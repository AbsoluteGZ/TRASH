# %%
import cv2
from ultralytics import YOLO
import math
import gdown
import moviepy
import IPython

# %%
# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 14.1MB/s]

# %%
gdown.download('https://drive.google.com/file/d/13eRGYGcC6XWc2MetAmvpZWmSEPAfqRDe/view?usp=sharing', fuzzy=True)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=13eRGYGcC6XWc2MetAmvpZWmSEPAfqRDe
# From (redirected): https://drive.google.com/uc?id=13eRGYGcC6XWc2MetAmvpZWmSEPAfqRDe&confirm=t&uuid=fb032145-d034-4de5-b9f1-cf8a9eeee942
# To: c:\Programing\cvtest - Trim.avi
# 100%|██████████| 375M/375M [00:26<00:00, 14.2MB/s]
# 'cvtest - Trim.avi'

# %%
# Initialize video capture
video_path = "cvtest - Trim.avi"

# %%
cap = cv2.VideoCapture(video_path)

# %%
# Check if video capture is successful
if not cap.isOpened():
    print("Error: Could not open video file.")
    exit()

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# Define the codec and create VideoWriter object
output_path = "output.avi" #Path to the video
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Loop through the video frames
while True:
    # Read a frame from the video
    ret, frame = cap.read()

    # If frame reading was not successful, break the loop
    if not ret:
        print("End of video stream or error.")
        break

    # Run YOLOv8 inference on the frame
    results = model(frame, stream=True)

    # Process each detected object
    for r in results:
        boxes = r.boxes

        for box in boxes:

            # Bounding Box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) #Преобразовать в integer

            #put box in source image
            cv2.rectangle(frame, (x1, y1), (x2, y2), (255,0,255), 3)

            #Confidence
            confidence = math.ceil((box.conf[0]*100))/100
            #print("Confidence---->", confidence)

            #Class Names
            cls = int(box.cls[0])
            #print("Class Name--->", classNames[cls])

            org = [x1, y1]
            font = cv2.FONT_HERSHEY_PLAIN
            fontScale = 2
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(frame, classNames[cls], org, font, fontScale, color, thickness)

    # Write the frame to the output video
    out.write(frame)


# Release the video capture object and close all windows
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Video saved to {output_path}")
# Out:
# 0: 384x640 2 persons, 2 cars, 1 truck, 52.5ms
# Speed: 6.7ms preprocess, 52.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 1 truck, 36.8ms
# Speed: 2.3ms preprocess, 36.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 1 truck, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 1 truck, 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 truck, 35.0ms
# Speed: 1.6ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 truck, 33.9ms
# Speed: 1.3ms preprocess, 33.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 truck, 33.9ms
# ...

# %%
from moviepy import VideoFileClip
from IPython.display import display, Video

path = "output.avi"

clip = VideoFileClip(path)
clip.write_videofile("temp.mp4", codec='libx264')  # Конвертация в mp4 для совместимости

# Отображение видео в Jupyter
display(Video("temp.mp4", width=960))
# Out:
# MoviePy - Building video temp.mp4.
# MoviePy - Writing video temp.mp4
# MoviePy - Done !
# MoviePy - video ready temp.mp4
# <video src="temp.mp4" controls  width="960" >
#       Your browser does not support the <code>video</code> element.
#     </video>
